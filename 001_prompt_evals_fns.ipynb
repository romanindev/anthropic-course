# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-haiku-4-5"

# %%
# Helper functions
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)


def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[]):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message.content[0].text

# %%
# Function to generate a new dataset
import json


def generate_dataset():
    prompt = """
Generate a evaluation dataset for a prompt evaluation. The dataset will be used to evaluate prompts
that generate Python, JSON, or Regex specifically for AWS-related tasks. Generate an array of JSON objects,
each representing task that requires Python, JSON, or a Regex to complete.

Example output:
```json
[
    {
        "task": "Description of task",
        "format": "json" or "python" or "regex",
        "solution_criteria": "Key criteria for evaluating the solution"
    },
    ...additional
]
```

* Focus on tasks that can be solved by writing a single Python function, a single JSON object, or a regular expression.
* Focus on tasks that do not require writing much code

Please generate 3 objects.
"""

    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```json")
    text = chat(messages, stop_sequences=["```"])
    return json.loads(text)

# %%
# Generate the dataset and write it to 'dataset.json'
dataset = generate_dataset()
with open("dataset.json", "w") as f:
    json.dump(dataset, f, indent=2)

# %%
# Function to grade a test case + output using a model
def grade_by_model(test_case, output):
    eval_prompt = f"""
You are an expert AWS code reviewer. Your task is to evaluate the following AI-generated solution.

Original Task:
<task>
{test_case["task"]}
</task>

Solution to Evaluate:
<solution>
{output}
</solution>

Criteria you should use to evaluate the solution:
<criteria>
{test_case["solution_criteria"]}
</criteria>

Output Format
Provide your evaluation as a structured JSON object with the following fields, in this specific order:
- "strengths": An array of 1-3 key strengths
- "weaknesses": An array of 1-3 key areas for improvement
- "reasoning": A concise explanation of your overall assessment
- "score": A number between 1-10

Respond with JSON. Keep your response concise and direct.
Example response shape:
{{
    "strengths": string[],
    "weaknesses": string[],
    "reasoning": string,
    "score": number
}}
    """

    messages = []
    add_user_message(messages, eval_prompt)
    add_assistant_message(messages, "```json")
    eval_text = chat(messages, stop_sequences=["```"])
    return json.loads(eval_text)

# %%
# Passes a test case into Claude
def run_prompt(test_case):
    prompt = f"""
Please solve the following task:

{test_case["task"]}

* Respond only with Python, JSON, or a plain Regex
* Do not add any comments or commentary or explanation
"""

    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```code")
    output = chat(messages, stop_sequences=["```"])
    return output

# %%
# Functions to validate the output structure
import re
import ast


def validate_json(text):
    try:
        json.loads(text.strip())
        return 10
    except json.JSONDecodeError:
        return 0


def validate_python(text):
    try:
        ast.parse(text.strip())
        return 10
    except SyntaxError:
        return 0


def validate_regex(text):
    try:
        re.compile(text.strip())
        return 10
    except re.error:
        return 0


def grade_syntax(response, test_case):
    format = test_case["format"]
    if format == "json":
        return validate_json(response)
    elif format == "python":
        return validate_python(response)
    else:
        return validate_regex(response)

# %%
# Function to execute a single test case and grade the output
def run_test_case(test_case):
    """Calls run_prompt, then grades the result"""
    output = run_prompt(test_case)

    model_grade = grade_by_model(test_case, output)
    model_score = model_grade["score"]
    reasoning = model_grade["reasoning"]

    syntax_score = grade_syntax(output, test_case)

    score = (model_score + syntax_score) / 2

    return {
        "output": output,
        "test_case": test_case,
        "score": score,
        "reasoning": reasoning,
    }

# %%
from statistics import mean


def run_eval(dataset):
    """Loads the dataset and calls run_test_case with each case"""
    results = []

    for test_case in dataset:
        result = run_test_case(test_case)
        results.append(result)

    average_score = mean([result["score"] for result in results])
    print(f"Average score: {average_score}")

    return results

# %%
with open("dataset.json", "r") as f:
    dataset = json.load(f)

results = run_eval(dataset)
# Out:
# Average score: 8.166666666666666

# %%
print(json.dumps(results, indent=2))
# Out:
# [
#   {
#     "output": "\nimport re\nimport json\nimport sys\n\ndef extract_aws_regions(text):\n    pattern = r'arn:aws:[^:]+:([a-z]{2}-[a-z]+-\\d):[\\d\\-]+:'\n    matches = re.findall(pattern, text)\n    return matches\n\nif __name__ == \"__main__\":\n    input_text = sys.stdin.read()\n    regions = extract_aws_regions(input_text)\n    print(json.dumps(regions))\n",
#     "test_case": {
#       "task": "Extract AWS region codes from CloudFormation template ARNs using a pattern like 'arn:aws:service:region:account-id:resource'",
#       "format": "regex",
#       "solution_criteria": "Regex should correctly capture region codes (e.g., us-east-1, eu-west-2) from AWS ARNs, handling multiple regions in a string"
#     },
#     "score": 7.5,
#     "reasoning": "The solution demonstrates understanding of the core requirement but has a critical flaw in the regex pattern. The pattern `[a-z]{2}-[a-z]+-\\d` will fail to capture valid AWS regions with multi-digit suffixes. For example, 'us-east-10' would not match because `\\d` only matches a single digit. This is a significant functional defect since AWS has released regions with higher numbering (e.g., eu-central-2). The pattern should use `\\d+` instead. Additionally, the lack of error handling makes the solution fragile for production use."
#   },
#   {
#     "output": "\nimport json\nimport re\nfrom typing import List, Set\n\ndef extract_principals_with_get_object(policy_json: str) -> Set[str]:\n    \"\"\"Extract all principals that have 's3:GetObject' permission from an S3 bucket policy.\"\"\"\n    try:\n        policy = json.loads(policy_json)\n    except json.JSONDecodeError:\n        return set()\n    \n    principals = set()\n    statements = policy.get('Statement', [])\n    \n    for statement in statements:\n        actions = statement.get('Action', [])\n        if isinstance(actions, str):\n            actions = [actions]\n        \n        has_get_object = any(\n            action == 's3:GetObject' or action == 's3:*' or action == '*'\n            for action in actions\n        )\n        \n        if has_get_object:\n            effect = statement.get('Effect', 'Allow')\n            if effect == 'Allow':\n                principal = statement.get('Principal', {})\n                \n                if isinstance(principal, str):\n                    principals.add(principal)\n                elif isinstance(principal, dict):\n                    if '*' in principal:\n                        principals.add('*')\n                    for key, values in principal.items():\n                        if isinstance(values, str):\n                            principals.add(values)\n                        elif isinstance(values, list):\n                            principals.update(values)\n    \n    return principals\n\n\nif __name__ == \"__main__\":\n    policy = {\n        \"Version\": \"2012-10-17\",\n        \"Statement\": [\n            {\n                \"Effect\": \"Allow\",\n                \"Principal\": {\n                    \"AWS\": \"arn:aws:iam::123456789012:root\"\n                },\n                \"Action\": \"s3:GetObject\",\n                \"Resource\": \"arn:aws:s3:::my-bucket/*\"\n            },\n            {\n                \"Effect\": \"Allow\",\n                \"Principal\": \"*\",\n                \"Action\": [\"s3:GetObject\", \"s3:PutObject\"],\n                \"Resource\": \"arn:aws:s3:::my-bucket/public/*\"\n            }\n        ]\n    }\n    \n    result = extract_principals_with_get_object(json.dumps(policy))\n    print(json.dumps(list(result), indent=2))\n",
#     "test_case": {
#       "task": "Parse an AWS S3 bucket policy JSON and extract all principals that have 's3:GetObject' permission",
#       "format": "python",
#       "solution_criteria": "Function should return a list of unique principals (ARNs or accounts) that have s3:GetObject permission, handling both wildcard and specific principals"
#     },
#     "score": 8.0,
#     "reasoning": "The solution correctly implements the core logic for extracting principals with GetObject permissions and handles common policy structures well. However, it has three notable gaps: (1) action matching is too strict and doesn't account for wildcard patterns that AWS IAM actually supports, (2) principal parsing doesn't handle all valid AWS policy formats (list-type principals, account ID strings), and (3) inconsistency between declared return type (Set) and criteria requirement (list). The solution would work for well-formed policies with explicit actions, but would miss valid principals in policies using action wildcards\u2014a realistic AWS scenario."
#   },
#   {
#     "output": "\n{\n  \"FunctionName\": \"my-function\",\n  \"Runtime\": \"python3.11\",\n  \"Role\": \"arn:aws:iam::123456789012:role/lambda-role\",\n  \"Handler\": \"index.handler\",\n  \"Code\": {\n    \"ZipFile\": \"def handler(event, context):\\n    return {'statusCode': 200, 'body': 'Hello'}\"\n  }\n}\n",
#     "test_case": {
#       "task": "Generate a minimal AWS Lambda function configuration JSON object with required fields: FunctionName, Runtime, Role, Handler, and Code",
#       "format": "json",
#       "solution_criteria": "JSON must be valid and include all required Lambda configuration fields with appropriate placeholder values that follow AWS naming conventions"
#     },
#     "score": 9.0,
#     "reasoning": "The solution fully satisfies the core requirement of providing a minimal, valid Lambda configuration with all required fields using appropriate AWS conventions. The JSON is syntactically correct and semantically sound. Minor inconsistency between Handler reference and Code structure is the only notable issue, though both interpretations are technically valid depending on deployment method."
#   }
# ]
