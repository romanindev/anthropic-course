# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-sonnet-4-5"

# %%
# Helper functions
from anthropic.types import Message


def add_user_message(messages, message):
    user_message = {
        "role": "user",
        "content": message.content if isinstance(message, Message) else message,
    }
    messages.append(user_message)


def add_assistant_message(messages, message):
    assistant_message = {
        "role": "assistant",
        "content": message.content if isinstance(message, Message) else message,
    }
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[], tools=None):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if tools:
        params["tools"] = tools

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message


def text_from_message(message):
    return "\n".join([block.text for block in message.content if block.type == "text"])

# %%
web_search_schema = {
    "type": "web_search_20250305",
    "name": "web_search",
    "max_uses": 5,
    "allowed_domains": ["nih.gov"],
}

# %%
messages = []
add_user_message(
    messages,
    """
    What's the best exercise for gaining leg muscle?
    """,
)
response = chat(messages, tools=[web_search_schema])
response
# Out:
# Message(id='msg_01EBHTLGsgPMiBdE5quS9P3v', container=None, content=[TextBlock(citations=None, text='Based on exercise science, **squats** are widely considered the best overall exercise for gaining leg muscle. Here\'s why:\n\n**Why Squats Are Superior:**\n- **Compound movement**: Works multiple major muscle groups simultaneously, including quadriceps, hamstrings, glutes, and calves\n- **Heavy loading potential**: Allows you to progressively overload with significant weight, which is crucial for muscle growth\n- **Functional strength**: Mimics natural movement patterns and builds overall lower body power\n- **Hormonal response**: Heavy compound exercises like squats trigger greater testosterone and growth hormone release\n\n**Other Excellent Options:**\n\n1. **Deadlifts** (especially Romanian deadlifts) - Excellent for hamstrings, glutes, and overall posterior chain\n2. **Bulgarian split squats** - Great for addressing muscle imbalances and building quad/glute strength\n3. **Leg press** - Allows very heavy loads with less technical demand, good for pure muscle building\n4. **Lunges** (walking or stationary) - Effective unilateral exercise for overall leg development\n\n**For Optimal Results:**\n- **Progressive overload**: Gradually increase weight, reps, or sets over time\n- **Variety**: Include both bilateral (squats, leg press) and unilateral (lunges, split squats) exercises\n- **Rep ranges**: Use 6-12 reps per set for hypertrophy (muscle growth)\n- **Frequency**: Train legs 2-3 times per week with adequate recovery\n\nThe "best" exercise ultimately depends on your individual goals, experience level, and any physical limitations, but squats remain the gold standard for comprehensive leg muscle development.', type='text')], model='claude-sonnet-4-5-20250929', role='assistant', stop_details=None, stop_reason='end_turn', stop_sequence=None, type='message', usage=Usage(cache_creation=CacheCreation(ephemeral_1h_input_tokens=0, ephemeral_5m_input_tokens=0), cache_creation_input_tokens=0, cache_read_input_tokens=0, inference_geo='not_available', input_tokens=2228, output_tokens=375, output_tokens_details=None, server_tool_use=None, service_tier='standard'))
